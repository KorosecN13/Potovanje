# %%
import pandas as pd

# %%
london = pd.read_csv('LONDON.csv')

# %%
london
# Out:
#                                            Ime hotela   Oddaljenost od centra  \
# 0                Park Plaza Westminster Bridge London                1.018110
# 1                                  K West Hotel & Spa                6.230678
# 2                                     The Ritz London                0.969306
# 3                                     Rosewood London                1.326971
# 4                The Park City Grand Plaza Kensington                4.465188
# 5                                     St Martins Lane                0.324401
# 6                         Courthouse Hotel Shoreditch                3.991183
# 7                                        Caesar Hotel                3.851820
# 8                           Fraser Suites Queens Gate                3.925468
# 9                   Citadines Trafalgar Square London                0.216809
# 10                           The Rubens At The Palace                1.468826
# ...

# %%
london('cena').mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2a3a97effc7b> in <module>()
# ----> 1 london('cena').mean
#
# TypeError: 'DataFrame' object is not callable

# %%
pd.london('cena').mean
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-bea9f2a2d839> in <module>()
# ----> 1 pd.london('cena').mean
#
# AttributeError: module 'pandas' has no attribute 'london'
